# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# from bs4 import BeautifulSoup
# import requests
from datetime import date

from   scipy.optimize import curve_fit
from   sklearn.linear_model import LinearRegression


# %matplotlib inline

# %%
og_covid_2020 = pd.read_csv('NYT_2020_county_covid_date.csv')
og_covid_2021 = pd.read_csv('NYT_2021_county_covid_date.csv')
og_internet_df = pd.read_csv('internet_data.csv',encoding='ISO-8859-1')
og_fips_to_zip = pd.read_csv('ZIP-COUNTY-FIPS_2017-06.csv')

# %%
covid_2020 = og_covid_2020.copy()
covid_2021 = og_covid_2021.copy()
internet_df = og_internet_df.copy()
fips_to_zip = og_fips_to_zip.copy()

# %%
covid_2020_21 = covid_2020.append(covid_2021)

# %%
covid_2020_21['date'] = pd.to_datetime(covid_2020_21['date'])
covid_2020_21.sort_values(by="date", inplace=True)
covid_2020_21['tot_deaths'] = covid_2020_21.groupby('county')['deaths'].cumsum(axis=0)
covid_2020_21['tot_cases'] = covid_2020_21.groupby('county')['cases'].cumsum(axis=0)
covid_2020_21['death_rate'] = covid_2020_21['tot_deaths'] / covid_2020_21['tot_cases']
covid_2020_21['fips_code'] = pd.to_numeric(covid_2020_21['geoid'].str.lstrip('USA-'))
covid_2020_21['dr_rating'] = pd.qcut(x=covid_2020_21.death_rate, q=6, labels = range(6))
covid_2020_21.drop(columns=['geoid'],inplace=True)

# %%
covid_2020_21.to_csv('/Users/josephgreene/Library/CloudStorage/Box-Box/project_county_covid_data')

# %%
covid_2020_21
# Out:
#               date     county           state  cases  cases_avg  \
# 0       2020-01-21  Snohomish      Washington      1       0.14
# 1       2020-01-22  Snohomish      Washington      0       0.14
# 2       2020-01-23  Snohomish      Washington      0       0.14
# 3       2020-01-24  Snohomish      Washington      0       0.14
# 4       2020-01-24       Cook        Illinois      1       0.14
# ...            ...        ...             ...    ...        ...
# 1042823 2021-11-17   Canadian        Oklahoma    206      29.43
# 1042824 2021-11-17      Caddo        Oklahoma     25       3.57
# 1042825 2021-11-17      Bryan        Oklahoma     69       9.86
# 1042815 2021-11-17     Cotton        Oklahoma     11       1.57
# 1044985 2021-11-17  St. Croix  Virgin Islands     10       6.86
#
#          cases_avg_per_100k  deaths  deaths_avg  deaths_avg_per_100k  \
# 0                      0.02       0         0.0                  0.0
# 1                      0.02       0         0.0                  0.0
# 2                      0.02       0         0.0                  0.0
# 3                      0.02       0         0.0                  0.0
# 4                      0.00       0         0.0                  0.0
# ...                     ...     ...         ...                  ...
# 1042823               19.84       0         0.0                  0.0
# 1042824               12.42       0         0.0                  0.0
# 1042825               20.54       0         0.0                  0.0
# 1042815               27.73       0         0.0                  0.0
# 1044985               13.55       0         0.0                  0.0
#
#          tot_deaths  tot_cases  death_rate  fips_code dr_rating
# 0                 0          1    0.000000      53061         0
# 1                 0          1    0.000000      53061         0
# 2                 0          1    0.000000      53061         0
# 3                 0          1    0.000000      53061         0
# 4                 0          1    0.000000      17031         0
# ...             ...        ...         ...        ...       ...
# 1042823         295      23744    0.012424      40017         1
# 1042824        1107      45150    0.024518      40015         4
# 1042825         180      15443    0.011656      40013         1
# 1042815          23       1006    0.022863      40033         4
# 1044985         122      18234    0.006691      78010         0
#
# [1933542 rows x 14 columns]

# %%
covid_2020_21.sample()
# Out:
#              date     county           state  cases  cases_avg  \
# 297357 2021-04-02  Lexington  South Carolina     69      50.86
#
#         cases_avg_per_100k  deaths  deaths_avg  deaths_avg_per_100k  \
# 297357               17.02       1        1.14                 0.38
#
#         tot_deaths  tot_cases  death_rate  fips_code dr_rating
# 297357         469      31701    0.014794      45063         2

# %%
temp_df = covid_2020_21.copy().groupby(by='date')

plot = plt.plot(temp_df.deaths.sum())
plt.figure(figsize=(24,8))

plt.show()

# %%
temp_df = covid_2020_21.groupby(by='county')
county_overall_df = temp_df.var()

# %%
# fig, ax = plt.subplots()
# ax.plot(temp_df.size())
# plt.ylabel('# counties reporting')
# plt.xlabel('Date')
# fig.set_size_inches(24,3)
# plt.title("# of Counties reporting each day".title())
# plt.show()

# %%
good_reporting = 3000

# %%
pd.value_counts(temp_df.size() >= 3000)
# Out:
# False    1850
# True       80
# dtype: int64

# %%
plt.plot(covid_2020_21.date,covid_2020_21.deaths.cumsum())

# %%
temp_df
temp_df.var()
# Out:
#                                   cases     cases_avg  cases_avg_per_100k  \
# county
# Abbeville                    117.555311     40.167678          667.732214
# Acadia                       777.544710    313.293579          813.827967
# Accomack                     116.192553     54.376679          520.698856
# Ada                        22793.388485  14970.667741          645.490924
# Adair                        176.949171     47.858702         1128.953246
# ...                                 ...           ...                 ...
# Yukon-Koyukuk Census Area     11.450652      3.057183         1117.860404
# Yuma                        7490.933853   5467.148893         1204.560467
# Zapata                        75.685457     25.152011         1251.057910
# Zavala                       131.904648     30.143308         2150.108646
# Ziebach                        6.605730      2.002574         2635.781704
#
#                              deaths  deaths_avg  deaths_avg_per_100k  \
# county
# Abbeville                  0.108380    0.015184             0.248787
# Acadia                     0.808327    0.215753             0.558824
# Accomack                   0.180352    0.034713             0.330766
# Ada                        5.494357    2.073266             0.089009
# Adair                      0.189821    0.024519             1.436079
# ...                             ...         ...                  ...
# Yukon-Koyukuk Census Area  0.015013    0.002010             0.739828
# Yuma                       4.684099    2.506089             0.900411
# Zapata                     0.117921    0.024052             1.194266
# Zavala                     0.182702    0.022849             1.623271
# Ziebach                    0.017539    0.004240             5.623732
#
#                               tot_deaths     tot_cases  death_rate  \
# county
# Abbeville                     295.741482  1.570481e+06    0.000057
# Acadia                       5896.851826  1.006567e+07    0.000165
# Accomack                      399.355838  1.287805e+06    0.000015
# Ada                         52026.839109  6.482325e+08    0.000029
# Adair                        4380.570739  1.877116e+07    0.000549
# ...                                  ...           ...         ...
# Yukon-Koyukuk Census Area       3.286688  4.110734e+04    0.000042
# Yuma                       113839.379950  2.391103e+08    0.000040
# Zapata                        266.808093  6.821003e+05    0.000055
# Zavala                        319.766256  7.689847e+05    0.000128
# Ziebach                        16.562872  2.267499e+04    0.000135
#
#                               fips_code
# county
# Abbeville                  0.000000e+00
# Acadia                     0.000000e+00
# Accomack                   0.000000e+00
# Ada                        0.000000e+00
# Adair                      6.829426e+07
# ...                                 ...
# Yukon-Koyukuk Census Area  0.000000e+00
# Yuma                       4.201839e+06
# Zapata                     0.000000e+00
# Zavala                     0.000000e+00
# Ziebach                    0.000000e+00
#
# [1930 rows x 10 columns]

# %%
internet_df = og_internet_df.copy()
fips_to_zip = og_fips_to_zip.copy()

# %%
col_to_keep_internet = [
    'Zip',
    'County',
    'State', 
    'AllProviderCount_2020', 
    'All25_3_2020', 
    'All100_3',
    'TestCount',
    'AverageMbps', 
    'FastestAverageMbps'
]
internet_df = internet_df.copy().loc[:,col_to_keep_internet]

# %%
internet_df
# Out:
#          Zip         County           State  AllProviderCount_2020  \
# 0      29620      Abbeville  South Carolina                   11.0
# 1      29628      Abbeville  South Carolina                    8.0
# 2      29638      Abbeville  South Carolina                   13.0
# 3      29639      Abbeville  South Carolina                    8.0
# 4      70516         Acadia       Louisiana                   12.0
# ...      ...            ...             ...                    ...
# 32603  99781  Yukon-Koyukuk          Alaska                    2.0
# 32604  99788  Yukon-Koyukuk          Alaska                    2.0
# 32605  99774  Yukon-Koyukuk          Alaska                    2.0
# 32606  99767  Yukon-Koyukuk          Alaska                    1.0
# 32607  99768  Yukon-Koyukuk          Alaska                    3.0
#
#        All25_3_2020  All100_3  TestCount  AverageMbps  FastestAverageMbps
# 0               7.0       3.0     2536.0       212.50              536.35
# 1               5.0       2.0      100.0        51.12              126.06
# 2               6.0       4.0      272.0        82.79              222.35
# 3               5.0       3.0      163.0        93.12              223.75
# 4               4.0       2.0       49.0         2.76                9.41
# ...             ...       ...        ...          ...                 ...
# 32603           0.0       0.0        8.0         0.43                0.51
# 32604           0.0       0.0        NaN          NaN                 NaN
# 32605           0.0       0.0        NaN          NaN                 NaN
# 32606           0.0       0.0        NaN          NaN                 NaN
# 32607           1.0       0.0        1.0         4.50                4.50
#
# [32608 rows x 9 columns]

# %%
internet_df = internet_df.groupby(by=['County','State']).mean()

# %%
col_to_sum = 'AllProviderCount_2020	All25_3_2020	All100_3	TestCount'.split('\t')
# internet_df[col_to_sum] = 
internet_df[col_to_sum].groupby(by=['County','State']).mean()
# internet_df[['County','All100_3']].groupby(by='County').mean()
# Out:
#                           AllProviderCount_2020  All25_3_2020  All100_3  \
# County    State
# Abbeville South Carolina              10.000000      5.750000  3.000000
# Acadia    Louisiana                   14.750000      6.000000  2.625000
# Accomack  Virginia                     9.913043      4.086957  1.826087
# Ada       Idaho                       15.000000      7.400000  3.733333
# Adair     Iowa                        16.500000      7.333333  4.833333
# ...                                         ...           ...       ...
# Yuma      Arizona                      8.857143      4.000000  2.714286
#           Colorado                    10.285714      5.000000  2.428571
# Zapata    Texas                       12.666667      3.333333  1.000000
# Zavala    Texas                       12.500000      4.500000  0.500000
# Ziebach   South Dakota                 8.500000      5.000000  2.000000
#
#                              TestCount
# County    State
# Abbeville South Carolina    767.750000
# Acadia    Louisiana        1034.250000
# Accomack  Virginia          895.571429
# Ada       Idaho           27114.200000
# Adair     Iowa              132.500000
# ...                                ...
# Yuma      Arizona         20486.600000
#           Colorado         2225.600000
# Zapata    Texas            1318.333333
# Zavala    Texas             696.000000
# Ziebach   South Dakota      204.000000
#
# [3213 rows x 4 columns]

# %%
fips_to_zip = og_fips_to_zip.copy()

# %%
# https://www.ssa.gov/international/coc-docs/states.html for list below (non-states except d.c. removed)
names_abbs = '''ALABAMA	AL
                ALASKA	AK
                ARIZONA	AZ
                ARKANSAS	AR
                CALIFORNIA	CA
                COLORADO	CO
                CONNECTICUT	CT
                DELAWARE	DE
                DISTRICT OF COLUMBIA	DC
                FLORIDA	FL
                GEORGIA	GA
                HAWAII	HI
                IDAHO	ID
                ILLINOIS	IL
                INDIANA	IN
                IOWA	IA
                KANSAS	KS
                KENTUCKY	KY
                LOUISIANA	LA
                MAINE	ME
                MARYLAND	MD
                MASSACHUSETTS	MA
                MICHIGAN	MI
                MINNESOTA	MN
                MISSISSIPPI	MS
                MISSOURI	MO
                MONTANA	MT
                NEBRASKA	NE
                NEVADA	NV
                NEW HAMPSHIRE	NH
                NEW JERSEY	NJ
                NEW MEXICO	NM
                NEW YORK	NY
                NORTH CAROLINA	NC
                NORTH DAKOTA	ND
                OHIO	OH
                OKLAHOMA	OK
                OREGON	OR
                PENNSYLVANIA	PA
                RHODE ISLAND	RI
                SOUTH CAROLINA	SC
                SOUTH DAKOTA	SD
                TENNESSEE	TN
                TEXAS	TX
                UTAH	UT
                VERMONT	VT
                VIRGINIA	VA
                WASHINGTON	WA
                WEST VIRGINIA	WV
                WISCONSIN	WI
                WYOMING	WY'''

names_abbs = [i.strip().split('\t') for i in names_abbs.split('\n')]
names_abbs = {i[0].title():i[1] for i in names_abbs}

names_abbs_df = pd.DataFrame({
    'State':names_abbs.keys(),
    'State_abbr':names_abbs.values()                        
                            })

# %%
# internet_df aning fips_to_zip df

col_to_keep_fips_to_zip = [
#     'ZIP',
    'COUNTYNAME', 
    'STATE',
    'STCOUNTYFP',
#   'CLASSFP'
    ]
fips_to_zip = fips_to_zip.loc[:,col_to_keep_fips_to_zip]
fips_to_zip.rename(columns={'ZIP':'Zip','STCOUNTYFP':"fips_code","STATE":"State_abbr","COUNTYNAME":"County"},inplace=True)
fips_to_zip['County'] = fips_to_zip.County.apply(lambda x: x[:-7])
fips_to_zip = pd.merge(fips_to_zip,names_abbs_df,on='State_abbr')
fips_to_zip.drop_duplicates(subset='fips_code',inplace=True)

# %%
internet_df.shape
# Out:
# (3213, 7)

# %%
internet_df = pd.merge(internet_df, fips_to_zip.loc[:,['County','fips_code','State']], on=['County','State'], how='left').sort_values(by='fips_code')

# %%
internet_df = internet_df.loc[pd.notnull(internet_df['fips_code'])].set_index('fips_code')

# %%
col_to_sum = 'AllProviderCount_2020	All25_3_2020	All100_3	TestCount'.split('\t')
# internet_df[col_to_sum] = 
# internet_df[col_to_sum] = internet_df[col_to_sum+['County','State']].groupby(by='County').mean()

# %%
internet_df['avg_mbps_rating'] = pd.qcut(x=internet_df.AverageMbps, q=6, labels = range(6))
internet_df['fast_mbps_rating'] = pd.qcut(x=internet_df.FastestAverageMbps, q=6, labels = range(6))

# %%
internet_df.drop(columns=['County','State','Zip','AllProviderCount_2020','All25_3_2020','All100_3','TestCount'], inplace=True)

# %%
internet_df.shape
# Out:
# (3054, 4)

# %%
internet_df.to_csv('project_county_internet_data')

# %%
internet_df
# Out:
#            AverageMbps  FastestAverageMbps avg_mbps_rating fast_mbps_rating
# fips_code
# 1001.0       38.218333           76.748333               3                2
# 1003.0       50.272632          140.296842               4                4
# 1005.0       52.206667          113.016667               4                4
# 1007.0       23.557143           60.075714               2                2
# 1009.0       29.145714           76.307143               2                2
# ...                ...                 ...             ...              ...
# 56037.0      20.593333           48.770000               1                1
# 56039.0      52.185000          111.310000               4                4
# 56041.0      25.090000           61.785000               2                2
# 56043.0      36.115000           62.090000               3                2
# 56045.0       9.170000           24.993333               0                0
#
# [3054 rows x 4 columns]
