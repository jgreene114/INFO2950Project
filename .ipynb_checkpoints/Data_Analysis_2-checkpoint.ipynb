# %% [markdown]
# ## Package import statements only

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import date

from   scipy.optimize import curve_fit
from   sklearn.linear_model import LinearRegression


# %matplotlib inline

# %%
import plotly as px

# %% [markdown]
# ## File imports only

# %%
og_time_srs_df = pd.read_csv('/Users/josephgreene/Library/CloudStorage/Box-Box/project_county_covid_data')
og_static_df = pd.read_csv('/Users/josephgreene/GitHub/INFO2950Project/project_county_static_data')

# %% [markdown]
# ### DF resets

# %%
time_srs_df = og_time_srs_df.copy()
static_df = og_static_df.copy()

# %% [markdown]
# ## Idea to consider
# Visualization: choose several days to look at distributions of death rates, see how country was handling cases at different points in pandemic?

# %% [markdown]
# # County Level
#
# ## Classification prediction model: Covid response grade and Internet access grade
# 1. Qcut the data
#     - Qcut death_rate into bins
#     - Qcut internet (create formula for internet access to account for avg. speed, # providers @ high//low speeds
# 2. Turn gradings into dummy col. (use OneHotEncoder)
# 3. Classification prediction
#     -
#
# ### Significance test: Bootstraps
#
# ## Linear regression model: Death rate and Average internet speed
# 1. Do linear regression model (linear)
#     - drop nans (death_rate and avg mbps)
#     - create LinearRegression obj.
#     - fit data
#
# 2. Do non-linear (ex decay?) model
#     - get log of death rate
#     - create linearRegression on x(avg mbps) and y(log(death_rate))
#
#
# ### Significant test: Permutations w/ 95% CI

# %% [markdown]
# ## Recleaning

# %%
time_srs_df
# Out:
#          Unnamed: 0        date      county       state  cases  deaths  \
# 0                 0  2020-01-21   Snohomish  Washington      1       0
# 1                 1  2020-01-22   Snohomish  Washington      0       0
# 2                 2  2020-01-23   Snohomish  Washington      0       0
# 3                 3  2020-01-24   Snohomish  Washington      0       0
# 4                 4  2020-01-24        Cook    Illinois      1       0
# ...             ...         ...         ...         ...    ...     ...
# 1069750     1069750  2021-02-25  Williamson   Tennessee     70       0
# 1069751     1069751  2021-02-25       White   Tennessee     11       1
# 1069752     1069752  2021-02-25     Weakley   Tennessee      3       0
# 1069753     1069753  2021-02-25      Borden       Texas      0       0
# 1069754     1069754  2021-02-25      Bosque       Texas      3       1
#
#          tot_deaths  tot_cases  death_rate  fips_code  dr_rating  \
# ...

# %%
# Cleaning the time series data

time_srs_df['date'] = pd.to_datetime(time_srs_df['date'])
time_srs_df.drop(columns='Unnamed: 0',inplace=True)

# Creating the current covid dataframe, containing the most recent date for covid data

current_covid = time_srs_df.loc[time_srs_df.date == time_srs_df.date.max()].copy()
current_covid['death_rate'] = current_covid['tot_deaths'] / current_covid['tot_cases']
current_covid.drop(columns=[
    'cases',
#     'cases_avg',
#     'cases_avg_per_100k',
    'deaths',
#     'deaths_avg',
#     'deaths_avg_per_100k',
#     'Unnamed: 0'
],inplace=True)

# %%
current_covid
# Out:
#               date      county      state  tot_deaths  tot_cases  death_rate  \
# 1067746 2021-02-25    Magoffin   Kentucky           1        865    0.001156
# 1067747 2021-02-25      McLean   Kentucky         248      16537    0.014997
# 1067748 2021-02-25    McCreary   Kentucky          25       1758    0.014221
# 1067749 2021-02-25   McCracken   Kentucky          67       5729    0.011695
# 1067750 2021-02-25       Mason   Kentucky         159       8319    0.019113
# ...            ...         ...        ...         ...        ...         ...
# 1069750 2021-02-25  Williamson  Tennessee         724      71445    0.010134
# 1069751 2021-02-25       White  Tennessee         334      18082    0.018471
# 1069752 2021-02-25     Weakley  Tennessee          59       3778    0.015617
# 1069753 2021-02-25      Borden      Texas           2         21    0.095238
# 1069754 2021-02-25      Bosque      Texas          30       1583    0.018951
#
# ...

# %%
# current_county_df is the most recent Covid data merged with static data by county

current_county_df = pd.merge(current_covid,static_df,left_on='fips_code', right_on='FIPS_Code',how='inner')
current_county_df.drop(columns=['Unnamed: 0'], inplace=True)
print(current_county_df.shape)
# Out:
# (1976, 14)

# %%
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6    0.192624
# 7    0.193810
# 8    0.200385
# 9    0.210824
# Name: stay_rate, dtype: float64

# %% [markdown]
# ## Cases and deaths over the last year

# %%
temp_df = time_srs_df.groupby(by=pd.to_datetime(time_srs_df.date)).sum()
fig, ax = plt.subplots()


sns.set_theme()

ax = sns.lineplot(
    x=temp_df.index,
    y=temp_df.cases.rolling(7).mean(),
    data=temp_df,
    color='red',
)

ax2 = ax.twinx()
ax2 = sns.lineplot(
    x=temp_df.index,
    y=temp_df.deaths.rolling(7).mean(),
    data=temp_df,
    color='blue'
)

sns.set(rc = {'figure.figsize':(20,10)})
plt.title('7-Day Rolling Average Covid Cases and Deaths over Time')
plt.xlabel('Date')
ax2.set_ylabel('Deaths')
ax.set_ylabel('Cases (millions)')

fig.legend(['Cases','Deaths'],loc='upper right', bbox_to_anchor=(.90, .875),prop={'size': 15})

plt.show()

# %%
temp_df.cases.rolling(7).mean()
# Out:
# date
# 2020-01-21             NaN
# 2020-01-22             NaN
# 2020-01-23             NaN
# 2020-01-24             NaN
# 2020-01-25             NaN
#                   ...
# 2021-02-21    66378.714286
# 2021-02-22    66977.428571
# 2021-02-23    68031.000000
# 2021-02-24    68607.142857
# 2021-02-25    64830.857143
# Name: cases, Length: 402, dtype: float64

# %%
temp_df = time_srs_df.groupby(by=pd.to_datetime(time_srs_df.date)).sum()

fig = px.line(temp_df, x=temp_df.index, y=temp_df.cases.rolling(7).mean())
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/pw/fvhf9ldx685f1wh3w9g6tqf00000gn/T/ipykernel_52046/4020702416.py in <module>
#       1 temp_df = time_srs_df.groupby(by=pd.to_datetime(time_srs_df.date)).sum()
#       2
# ----> 3 fig = px.line(temp_df, x=temp_df.index, y=temp_df.cases.rolling(7).mean())
#       4 fig.show()
#
# AttributeError: module 'plotly' has no attribute 'line'

# %%
df = px.data.gapminder().query("country=='Canada'")
fig = px.line(df, x="year", y="lifeExp", title='Life expectancy in Canada')
fig.show()

# %% [markdown]
# ## Linear Regression Model

# %%
def remove_outliers(df, col, l_ptile, u_ptile):
    q1 = df[col].quantile(l_ptile)
    q3 = df[col].quantile(u_ptile)
    iqr = q3-q1

    upper = q3 + iqr
    lower = q1 - iqr
    
    return df.loc[((lower < df[col]) & (df[col] < upper))]

# permute func. from Lec. 14

def permute(input_array):
    # shuffle is inplace, so copy to preserve input
    permuted = input_array.copy().values #convert to numpy array, avoiding warning
    np.random.shuffle(permuted)
    return pd.Series(permuted) # convert back to pandas

def create_reg_scatter(x,
#                        x_rt,
                       x_label,
#                        x_rt_label,
                       data=current_county_df,
                       y='death_rate',
                       y_rt='dr_rating',
                       y_label='Death Rate (Cumulative Cases/Deaths)'):
    data_for_regression = data.dropna(subset=[x,y])
    
    current_linear_regression = LinearRegression()
    current_linear_regression.fit(data_for_regression[[x]], data_for_regression[y])
    y_pred = current_linear_regression.predict(data_for_regression[[x]])
    
    plt.figure(figsize=(12,10));

    fig, ax = plt.subplots();

    ax = sns.scatterplot(
        x=x,
        y=y,
        data=data_for_regression,
        alpha=.5,
#         hue=x_rt,
    #     style='dr_rating',

    );

    ax2 = sns.lineplot(
        x=x,
        y=y_pred,
        color='darkorange',
        data=data_for_regression,
    );

    date = str(data.loc[0]['date'].date())

    plt.title(f'{y_label} vs. {x_label} as of {date}'.title())
    plt.xlabel(x_label)
    plt.ylabel(y_label)
#     plt.legend([x_rt_label])
    plt.show();
    
def plot_model_line(df,x,y, model, is_resampled=True):
    '''
    Takes a dataframe and a fitted model
    Plots a line of best fit to the data
    '''
    if is_resampled:
        color="grey"
        alpha=0.1
    else:
        color="steelblue"
        alpha=0.7
    plt.plot(df[x], df[x] * model.coef_[0] + model.intercept_, color=color, alpha=alpha)

# %%
plt.figure(figsize=(10,7))

plot = sns.heatmap(current_county_df.corr(),center=0,cmap='coolwarm', )
plt.tight_layout()

plt.show()

# %%
create_reg_scatter(x='AverageMbps',x_label='Average Mb/s')

# %%
create_reg_scatter(x='med_income',x_label="Median Income (2019)")

# %%
create_reg_scatter(x='rec_stay_rate', x_label='Recent Travel')

# %%
data_for_regression = current_county_df.dropna(subset=['death_rate','AverageMbps'])

# data_for_regression = remove_outliers(data_for_regression, 'AverageMbps', .05,.95)
# data_for_regression = remove_outliers(data_for_regression, 'death_rate', 0, .95)

# %%
current_linear_regression = LinearRegression()
current_linear_regression.fit(data_for_regression[['AverageMbps']], data_for_regression['death_rate'])
y_pred = current_linear_regression.predict(data_for_regression[['AverageMbps']])

# plot = plt.plot()
plt.figure(figsize=(12,10))

fig, ax = plt.subplots()

ax = sns.scatterplot(
    x='AverageMbps',
    y='death_rate',
    data=data_for_regression,
    alpha=.5,
    hue='avg_mbps_rating',
#     style='dr_rating',
    
)

ax2 = sns.lineplot(
    x='AverageMbps',
    y=y_pred,
    color='darkorange',
    data=data_for_regression,
)

date = str(data_for_regression.loc[0]['date'].date())



plt.title(f'Death Rate vs. Average Internet Speed as of {date}')
plt.xlabel('Average Mb/s')
plt.ylabel('Death Rate (Cumulative Deaths/Cases)')
plt.show()

# %%
r2 = current_linear_regression.score(data_for_regression[['AverageMbps']], data_for_regression['death_rate'])
print(f'r^2 score: {r2}')
# Out:
# r^2 score: 0.021101590530192116

# %%
current_linear_regression.coef_
# Out:
# array([-3.42586319e-05])

# %%
permute(current_county_df.death_rate)
# Out:
# 0       0.006397
# 1       0.015824
# 2       0.019638
# 3       0.013260
# 4       0.010327
#           ...
# 3244    0.018402
# 3245    0.011026
# 3246    0.017651
# 3247    0.007333
# 3248    0.024892
# Length: 3249, dtype: float64

# %%
x = 'AverageMbps'
y = 'death_rate'
df = data_for_regression.copy()

# plot one instance of permuted data
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,6), sharey=True)
sns.regplot(x=df[x], y=df[y], ax=ax1)
ax1.set_title('True data')
sns.regplot(x=df[x], y=permute(df[y]), ax=ax2)
ax2.set_title('Permuted data')
plt.show()

# %%
class Variable:
    def __init__(self, x, x_label):
        self.x = x
        self.x_label = x_label
        self.y = 'death_rate'
        self.y_label='Death Rate'
        
        self.data = current_county_df.dropna(subset=[self.y, self.x])
        
    def reg_scatter(self):
        create_reg_scatter(self.x, self.x_label)
        
    def perm_reg_scatter(self):
        
        # from lecture:

        plt.figure(figsize=(10,10))

        # plot true data
        plt.scatter(x=self.data[self.x], y=self.data[self.y], alpha=.3)

        # plot 100 iterations of models on permuted data
        for i in range(100):
            permuted_model = LinearRegression().fit(self.data[[self.x]], permute(self.data[self.y]))
            plot_model_line(self.data, self.x, self.y, permuted_model)

        # model true data and plot
        model = LinearRegression().fit(self.data[[self.x]], self.data[self.y])
        plot_model_line(self.data, self.x, self.y, model, is_resampled=False)

        plt.xlabel(self.x_label)
        plt.ylabel(self.y_label)

        plt.show()

# %%
int_speed = Variable('AverageMbps', 'Avg Mb/s')

# %%
int_speed.perm_reg_scatter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pw/fvhf9ldx685f1wh3w9g6tqf00000gn/T/ipykernel_52046/1714468454.py in <module>
# ----> 1 int_speed.perm_reg_scatter()
#
# /var/folders/pw/fvhf9ldx685f1wh3w9g6tqf00000gn/T/ipykernel_52046/3893351618.py in perm_reg_scatter(self)
#      21
#      22         # plot 100 iterations of models on permuted data
# ---> 23         for i in range(perm_n):
#      24             permuted_model = LinearRegression().fit(self.data[[self.x]], permute(self.data[self.y]))
#      25             plot_model_line(self.data, self.x, self.y, permuted_model)
#
# NameError: name 'perm_n' is not defined

# %%
create_reg_scatter(x,
#                        x_rt,
                       x_label,
#                        x_rt_label,
                       data=current_county_df,
                       y='death_rate',
                       y_rt='dr_rating',
                       y_label='Death Rate (Cumulative Cases/Deaths)'):

# %%
def create_perm_reg_scatter(
    x,
    x_label,
    perm_n=100,
    data=current_county_df,
    y='death_rate',
    y_label='Death Rate',
):
    
    df = data.dropna(subset=[y,x])
    
    # from lecture:
    
    plt.figure(figsize=(10,10))
    
    # plot true data
    plt.scatter(x=df[x], y=df[y], alpha=.3)

    # plot 100 iterations of models on permuted data
    for i in range(perm_n):
        permuted_model = LinearRegression().fit(df[[x]], permute(df[y]))
        plot_model_line(df, x, y, permuted_model)

    # model true data and plot
    model = LinearRegression().fit(df[[x]], df[y])
    plot_model_line(df, x, y, model, is_resampled=False)

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    plt.show()

# %%
plot1 = create_perm_reg_scatter(x='AverageMbps',x_label='Avg Mb/s');

# %%
plot1
plt.show()

# %%
create_perm_reg_scatter(x='med_income',x_label="Median Income (2019)")

# %%
plt.figure(figsize=(10,10))
# plot true data
plt.scatter(x=df[x], y=df[y], alpha=.3)

# plot 100 iterations of models on permuted data
for i in range(100):
    permuted_model = LinearRegression().fit(df[[x]], permute(df[y]))
    plot_model_line(data_for_regression, x, y, permuted_model)

# model true data and plot
model = LinearRegression().fit(df[[x]], df[y])
plot_model_line(df, x, y, model, is_resampled=False)

plt.show()

# %%
# what fraction of permuted (null hyopthesis) slopes are greater than our observed slope?
steeper_slopes = 0
n_permutations = 1000
permuted_slopes = np.zeros(n_permutations) # preallocate array of correct size

for i in range(n_permutations):
    permuted_model = LinearRegression().fit(df[[x]], permute(df[y]))
    
    permuted_slopes[i] = permuted_model.coef_[0]
    
    if np.abs(permuted_model.coef_[0]) > np.abs(model.coef_):
        steeper_slopes += 1
    
print(f'Fraction of permuted slopes more extreme than observed slopes: {steeper_slopes / n_permutations}')
# Out:
# Fraction of permuted slopes more extreme than observed slopes: 0.0

# %%
df_permuted_slopes = pd.DataFrame({'permuted_slopes': np.array(permuted_slopes)})

# %%
binsizes, _, _ = plt.hist(permuted_slopes, bins=50)
plt.vlines(model.coef_[0], ymin=0, ymax=np.max(binsizes), color='red')
plt.vlines(df_permuted_slopes.quantile(.95),  ymin=0, ymax=np.max(binsizes), color='green')
plt.vlines(df_permuted_slopes.quantile(.05),  ymin=0, ymax=np.max(binsizes), color='green')

plt.show()

# %% [markdown]
# REJECT THE NULL

# %%
plot = sns.regplot(
    x='AverageMbps',
    y='death_rate',
    data=current_county_df[current_county_df.AverageMbps < 150],
#     alpha=.35,
    
)

plot.figure.set_size_inches(20,10)

# %%
boxplot = sns.boxplot(
    x='avg_mbps_rating',
    y='death_rate',
    data=current_county_df
)
boxplot.figure.set_size_inches(8,12)

# %%
sns.boxplot(
    x= 'dr_rating', #'avg_mbps_rating',
    y= 'AverageMbps', # 'death_rate',
    data=current_county_df
)

# %%
plot = sns.displot(
    current_county_df,
    x = 'death_rate',
    hue = 'avg_mbps_rating',
    kind = 'kde',
    fill = True
    
)
plot.figure.set_size_inches(25,10)

# %%
time_srs_df.loc[time_srs_df.county == 'Tompkins'].cases.rolling(7).mean().plot()
# Out:
# <AxesSubplot:>

# %%
time_srs_df
# Out:
#               date      county       state  cases  deaths  tot_deaths  \
# 0       2020-01-21   Snohomish  Washington      1       0           0
# 1       2020-01-22   Snohomish  Washington      0       0           0
# 2       2020-01-23   Snohomish  Washington      0       0           0
# 3       2020-01-24   Snohomish  Washington      0       0           0
# 4       2020-01-24        Cook    Illinois      1       0           0
# ...            ...         ...         ...    ...     ...         ...
# 1069750 2021-02-25  Williamson   Tennessee     70       0         724
# 1069751 2021-02-25       White   Tennessee     11       1         334
# 1069752 2021-02-25     Weakley   Tennessee      3       0          59
# 1069753 2021-02-25      Borden       Texas      0       0           2
# 1069754 2021-02-25      Bosque       Texas      3       1          30
#
#          tot_cases  death_rate  fips_code  dr_rating  rec_stay_rate  \
# ...

# %%
current_county_df.groupby('dr_rating').size()

# %%
current_county_df.death_rate.plot.hist()

# %%
current_county_df.AverageMbps.plot.hist()

# %%
current_county_df.dr_rating.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
current_county_df.avg_mbps_rating.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# # Cleaning the county (covid) data

# time_srs_df['date'] = pd.to_datetime(time_srs_df['date'])
# # time_srs_df.drop(columns='Unnamed: 0',inplace=True)
# rand_covid_df = time_srs_df.loc[time_srs_df.date == np.random.choice(time_srs_df.date)].copy()
# rand_covid_df['death_rate'] = rand_covid_df['tot_deaths'] / rand_covid_df['tot_cases']
# rand_covid_df.drop(columns=[
#     'cases',
#     'cases_avg',
# #     'cases_avg_per_100k',
#     'deaths',
#     'deaths_avg',
# #     'deaths_avg_per_100k'
# ],inplace=True)
# rand_current_county_df = pd.merge(rand_covid_df,static_df,on='fips_code',how='left')

# plot = sns.regplot(
#     x='AverageMbps',
#     y='death_rate',
#     data=rand_current_county_df[rand_current_county_df.AverageMbps < 150],
# #     alpha=.35,
    
# )

# plot.figure.set_size_inches(10,5)
# print(pd.to_datetime(rand_current_county_df.date.unique()[0]))

# %%
print("Most recent Covid Data")
rand_current_county_df.drop(columns=['fips_code']).corr().style.background_gradient(
    cmap='RdYlGn', 
    axis=None,
    vmin=-0.8, 
    vmax=0.8
)

# %%
sns.lineplot(
    # data=,
    x='date',
    y='death_rate'
)

# %%
time_srs_df.groupby('date').deaths.cumsum().plot()
